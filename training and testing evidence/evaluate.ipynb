# %%
from utils.evaluator import Evaluation
evaluation = Evaluation()
# Out:
# Files already downloaded and verified

# %%
evaluation.visualise_dataset(dataset_name='mnist')
evaluation.visualise_dataset(dataset_name='caltech')

# %%
evaluation.plot_training_progress(metric_name='loss', dataset_name='mnist')
evaluation.plot_training_progress(metric_name='accuracy', dataset_name='mnist')

# %%
evaluation.plot_training_progress(metric_name='loss', dataset_name='caltech')
evaluation.plot_training_progress(metric_name='accuracy', dataset_name='caltech')

# %%
evaluation.compare_computational_performace(metric_name='epoch_time', dataset_name='mnist')
evaluation.compare_computational_performace(metric_name='it_per_sec', dataset_name='mnist')
# Out:
# Epoch_time
# ResNet (fine-tuned) = [58.90839171409607, 54.653817892074585, 54.1452271938324, 54.89857769012451, 54.60292053222656]
# ResNet (baseline) = [58.286410331726074, 54.567750692367554, 54.22691583633423, 54.38231706619263, 53.99718880653381]
# VGG11 (fine-tuned) = [377.44973635673523, 374.47036600112915, 374.14243960380554, 373.6918864250183, 373.3702688217163]
# VGG11 (baseline) = [379.13235425949097, 374.7549707889557, 374.327556848526, 374.443745136261, 359.6923871040344]
# It_per_sec
# ResNet (fine-tuned) = [31.829081484689983, 34.306843918984406, 34.629091005339404, 34.153890299006534, 34.3388225707337]
# ResNet (baseline) = [32.16873348914082, 34.36095452368093, 34.576924965805894, 34.478119012799745, 34.724029925297145]
# VGG11 (fine-tuned) = [19.87019536002961, 20.028287098096797, 20.045841385815656, 20.070010274373146, 20.08729839059906]
# VGG11 (baseline) = [19.782009938584, 20.013076769096802, 20.035928060286842, 20.029710997764784, 20.851150229739954]

# %%
evaluation.compare_computational_performace(metric_name='epoch_time', dataset_name='caltech')
evaluation.compare_computational_performace(metric_name='it_per_sec', dataset_name='caltech')
# Out:
# Epoch_time
# ResNet (fine-tuned) = [379.7867567539215, 376.82532000541687, 365.39205598831177, 375.16757011413574, 377.83213901519775, 376.203088760376, 371.39670300483704, 363.28106665611267, 369.9181938171387, 375.97878336906433]
# ResNet (baseline) = [388.62178444862366, 383.40017557144165, 386.39829778671265, 384.39810395240784, 390.0022485256195, 384.79715752601624, 368.2009811401367, 379.1001121997833, 378.49740195274353, 362.19855880737305]
# VGG11 (fine-tuned) = [400.0471565723419, 404.32573080062866, 421.90167903900146, 425.8971645832062, 428.40553069114685, 427.9017322063446, 423.3976135253906, 420.8896224498749, 422.7976725101471, 425.1036071777344]
# VGG11 (baseline) = [502.3359224796295, 389.4031994342804, 392.6030921936035, 404.66222047805786, 389.5170304775238, 388.0203785896301, 390.5882170200348, 391.0934624671936, 385.5786123275757, 393.43363547325134]
# It_per_sec
# ...

# %%
evaluation.plot_train_vs_test(dataset_name='mnist')
# Out:
# ...
# 100%|██████████| 625/625 [56:57<00:00,  5.47s/it]
# ResNet (fine-tuned) test accuracy: 0.9917
# ResNet (baseline) test accuracy: 0.9907
# VGG1 (fine-tuned) test accuracy: 0.9872
# VGG1 (baseline) test accuracy: 0.9897

# %%
evaluation.plot_train_vs_test(dataset_name='caltech')
# Out:
# ...
# 100%|██████████| 109/109 [11:43<00:00,  6.45s/it]
# ResNet (fine-tuned) test accuracy: 0.9556451612903226
# ResNet (baseline) test accuracy: 0.8617511520737328
# VGG1 (fine-tuned) test accuracy: 0.7350230414746544
# VGG1 (baseline) test accuracy: 0.08813364055299538

# %%
evaluation.get_quanti_metrics(dataset_name='mnist')
# Out:
# Make predictions on the testing dataset for the fine-tuned ResNet model.
# 100%|██████████| 625/625 [02:21<00:00,  4.42it/s]
# Make predictions on the testing dataset for the baseline ResNet model.
# 100%|██████████| 625/625 [02:21<00:00,  4.42it/s]
# Make predictions on the testing dataset for the fine-tuned VGG11 model.
# 100%|██████████| 625/625 [38:46<00:00,  3.72s/it]
# Make predictions on the testing dataset for the baseline VGG11 model.
# 100%|██████████| 625/625 [37:46<00:00,  3.63s/it]
# {'ResNet (fine-tuned)': {'precision': 0.9918593050952159,
#   'recall': 0.9914324564232849,
#   'f1': 0.9916246517681403,
#   'support': None},
#  'ResNet (baseline)': {'precision': 0.9906248514451684,
#   'recall': 0.990649953351571,
#   'f1': 0.9906206303378108,
#   'support': None},
#  'VGG11 (fine-tuned)': {'precision': 0.9873193606414643,
#   'recall': 0.9870502971630255,
#   'f1': 0.9871663189092275,
#   'support': None},
#  'VGG11 (baseline)': {'precision': 0.9895882870923938,
# ...

# %%
evaluation.get_quanti_metrics(dataset_name='caltech')
# Out:
# Make predictions on the testing dataset for the fine-tuned ResNet model.
# 100%|██████████| 109/109 [04:39<00:00,  2.56s/it]
# Make predictions on the testing dataset for the baseline ResNet model.
# 100%|██████████| 109/109 [04:24<00:00,  2.42s/it]
# Make predictions on the testing dataset for the fine-tuned VGG11 model.
# 100%|██████████| 109/109 [08:13<00:00,  4.52s/it]
# Make predictions on the testing dataset for the baseline VGG11 model.
# 100%|██████████| 109/109 [08:15<00:00,  4.54s/it]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
evaluation.plot_successes(dataset_name='mnist', model_name='resnet')
evaluation.plot_successes(dataset_name='mnist', model_name='vgg')

evaluation.plot_failures(dataset_name='mnist', model_name='resnet')
evaluation.plot_failures(dataset_name='mnist', model_name='vgg')
# Out:
# ...
#   7%|▋         | 45/625 [03:21<43:10,  4.47s/it]

# %%
evaluation.plot_successes(dataset_name='caltech', model_name='resnet')
evaluation.plot_successes(dataset_name='caltech', model_name='vgg')

evaluation.plot_failures(dataset_name='caltech', model_name='resnet')
evaluation.plot_failures(dataset_name='caltech', model_name='vgg')
# Out:
# ...
#   3%|▎         | 3/109 [00:19<11:42,  6.63s/it]

# %%
evaluation.plot_confusion_matrix(dataset_name='mnist')
# Out:
# Make predictions on the testing dataset for the fine-tuned ResNet model.
# 100%|██████████| 625/625 [02:24<00:00,  4.33it/s]
# Make predictions on the testing dataset for the baseline ResNet model.
# 100%|██████████| 625/625 [02:25<00:00,  4.28it/s]
# Make predictions on the testing dataset for the fine-tuned VGG11 model.
# 100%|██████████| 625/625 [37:22<00:00,  3.59s/it]
# Make predictions on the testing dataset for the baseline VGG11 model.
# 100%|██████████| 625/625 [36:39<00:00,  3.52s/it]

# %%
# evaluation.plot_confusion_matrix(dataset_name='caltech')
